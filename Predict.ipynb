# %%
# Initialize Modules

import librosa 
import librosa.display
import IPython
from IPython.display import Audio

# Module Imports
import utils
from Classifier import Classifier

# Initialize Classes
classifier = Classifier()

# %%
# Initialize Parameters
clip_duration = 3
song_offset = 60

# Preview Audio Clip

audio_recording = "./data/reminder.mp3"
data,sr=librosa.load(audio_recording, duration=clip_duration, offset=song_offset)
IPython.display.Audio(data,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
classifier.classify_song(audio_recording, song_offset, clip_duration)
# Out:
# 1/1 [==============================] - 0s 72ms/step
# Classification:  hiphop
# array(['hiphop'], dtype=object)
